# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv(r"../../data/income.csv",names=["name","income"],skiprows=1)
# Out:
#         name    income
# 0        Rob      5000
# 1      Rafiq      6000
# 2       Nina      4000
# 3      Sofia      7500
# 4      Mohan      8000
# 5        Tao      7000
# 6  Elon Musk  10000000

# %%
# Out:
#              income
# count  7.000000e+00
# mean   1.433929e+06
# std    3.777283e+06
# min    4.000000e+03
# 25%    5.500000e+03
# 50%    7.000000e+03
# 75%    7.750000e+03
# max    1.000000e+07

# %%
# Out:
# 5500.0

# %%
# Out:
# 6000

# %%
# Out:
# 5000

# %%
# Out:
# 10000000.0

# %%
perc_99=df['income'].quantile(0.99)
# Out:
# 9400479.999999994

# %%
df[df['income']>perc_99]
# Out:
#         name    income
# 6  Elon Musk  10000000

# %%
new_df= df[df['income']<perc_99]
# Out:
#     name  income
# 0    Rob    5000
# 1  Rafiq    6000
# 2   Nina    4000
# 3  Sofia    7500
# 4  Mohan    8000
# 5    Tao    7000

# %%
df.replace(df['income'][3],np.NaN,inplace=True)
# Out:
#         name      income
# 0        Rob      5000.0
# 1      Rafiq      6000.0
# 2       Nina      4000.0
# 3      Sofia         NaN
# 4      Mohan      8000.0
# 5        Tao      7000.0
# 6  Elon Musk  10000000.0

# %%
# Out:
# 1671666.6666666667

# %%
new_df=df.fillna(df['income'].median())
# Out:
#         name      income
# 0        Rob      5000.0
# 1      Rafiq      6000.0
# 2       Nina      4000.0
# 3      Sofia      6500.0
# 4      Mohan      8000.0
# 5        Tao      7000.0
# 6  Elon Musk  10000000.0

# %%
# Out:
# 0        4000.0
# 1        5000.0
# 2        6000.0
# 3        7000.0
# 4        8000.0
# 5    10000000.0
# Name: income, dtype: float64
