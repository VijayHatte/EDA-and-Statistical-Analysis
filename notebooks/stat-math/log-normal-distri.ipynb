# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"../../data/income (1).csv",index_col=None,names=['income','count'],skiprows=1)
# Out:
#    income  count
# 0    5000   4371
# 1   10000   3295
# 2   15000   5825
# 3   20000   6047
# 4   25000   6097

# %%
# Out:
# <Axes: xlabel='income'>

# %%
df['log_income'] = np.log(df['income'])
df
# Out:
# <Axes: xlabel='log_income'>
