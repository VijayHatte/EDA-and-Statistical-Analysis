# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
df = pd.read_csv(r"../../data/revenue.csv")
# Out:
#          company  revenue
# 0         Tesla      31.0
# 1           UBER     11.0
# 2         Amazon    386.0
# 3  Jindal  Steel      4.7
# 4      Axis Bank      5.6
# 5        Vedanta     11.3

# %%
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
plt.bar(df['company'],df['revenue'])
plt.xlabel("company")
# Out:
# Text(0, 0.5, 'revenue')

# %%
# Out:
# <Axes: xlabel='company'>
